# %%
# Importing the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib
# Out:
# Using matplotlib backend: Qt5Agg

# %%
# Loading the eda dataset

# %%
life_expectancy = pd.read_csv('C:/Users/pc/Documents/DigiCAP/PythonExx/data/LifeExpectancyData.csv')

# %%
life_expectancy
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
# First, we use the shape attribute to check the number of observstions and number of variables in the data

# %%
life_expectancy.shape
# Out:
# (2938, 22)

# %%
# Using the head function to check the top records

# %%
life_expectancy.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
# Next, we use the info function to check the information about the data and datatypes of each attribute in the data set

# %%
life_expectancy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
# The describe function shows how data is spread numerically by indicating the mean, minimum values,
# maximum values, standard deviations, the first, second and third quartiles in that data set"

# %%
life_expectancy.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %%
# checking for any missing values in any of the coulmns life expectancy data

# %%
life_expectancy.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
# Which countries have the higher life expectancy?
# What is the ratio of Adult Mortality to Child mortality?
# Which countries have the least cases of measles?
# Which countries have the least records of child under five deaths?
# Which countries have the highest records of child under five deaths?
# Does a country's GDP correspond with the number of its educated popu

# %%
# Remove some columns we may not need from the data so it can improve speed for processing
# Columns to be removed include Alcohol, Hepatitis B, BMI, Total expenditure, HIV/AIDS and Population

# %%
expectancies = life_expectancy.drop(['Alcohol','Hepatitis B', 'Total expenditure', 'Population' ], axis=1, inplace=True)

# %%
expectancies

# %%
life_expectancy.shape
# Out:
# (2938, 18)

# %%
print("Number of records (Countries): ", life_expectancy.shape[0])
print("Number of columns (features): ", life_expectancy.shape[1])
# Out:
# Number of records (Countries):  2938
# Number of columns (features):  18

# %%
expectancies

# %%
life_expectancy.dtypes
# Out:
# Country                             object
# Year                                 int64
# Status                              object
# Life expectancy                    float64
# Adult Mortality                    float64
# infant deaths                        int64
# percentage expenditure             float64
# Measles                              int64
#  BMI                               float64
# under-five deaths                    int64
# Polio                              float64
# Diphtheria                         float64
#  HIV/AIDS                          float64
# GDP                                float64
#  thinness  1-19 years              float64
#  thinness 5-9 years                float64
# Income composition of resources    float64
# Schooling                          float64
# dtype: object

# %%
columns_removed = life_expectancy.drop([ ' BMI ', ' HIV/AIDS' ], axis=1, inplace=True)

# %%
life_expectancy.dtypes
# Out:
# Country                             object
# Year                                 int64
# Status                              object
# Life expectancy                    float64
# Adult Mortality                    float64
# infant deaths                        int64
# percentage expenditure             float64
# Measles                              int64
# under-five deaths                    int64
# Polio                              float64
# Diphtheria                         float64
# GDP                                float64
#  thinness  1-19 years              float64
#  thinness 5-9 years                float64
# Income composition of resources    float64
# Schooling                          float64
# dtype: object

# %%
life_expectancy.count()
# Out:
# Country                            2938
# Year                               2938
# Status                             2938
# Life expectancy                    2928
# Adult Mortality                    2928
# infant deaths                      2938
# percentage expenditure             2938
# Measles                            2938
# under-five deaths                  2938
# Polio                              2919
# Diphtheria                         2919
# GDP                                2490
#  thinness  1-19 years              2904
#  thinness 5-9 years                2904
# Income composition of resources    2771
# Schooling                          2775
# dtype: int64

# %%
# Checking for missing or null values in the Polio coulmn

# %%
life_expectancy['Polio'].value_counts(dropna=False)
# Out:
# 99.0    376
# 98.0    255
# 96.0    207
# 97.0    205
# 95.0    180
#        ...
# 48.0      2
# 39.0      2
# 17.0      1
# 23.0      1
# 33.0      1
# Name: Polio, Length: 74, dtype: int64

# %%
# Checking for missing or null values in the GDP coulmn

# %%
life_expectancy['GDP'].value_counts(dropna=False)
# Out:
# NaN             448
# 1276.265000       1
# 3638.959460       1
# 2158.299000       1
# 1768.921320       1
#                ...
# 445.188660        1
# 2843.636350       1
# 1792.384500       1
# 14125.961000      1
# 246.375621        1
# Name: GDP, Length: 2491, dtype: int64

# %%
# Checking for missing or null values in the Schooling coulmn

# %%
life_expectancy['Schooling'].value_counts(dropna=False)
# Out:
# NaN     163
# 12.9     58
# 13.3     52
# 12.5     49
# 12.8     46
#        ...
# 2.8       1
# 19.8      1
# 20.5      1
# 19.7      1
# 20.7      1
# Name: Schooling, Length: 174, dtype: int64

# %%
# Removing columns with nulls

# %%
remove_null_columns = life_expectancy.dropna()

# %%
life_expectancy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 16 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   percentage expenditure           2938 non-null   float64
#  7   Measles                          2938 non-null   int64
#  8   under-five deaths                2938 non-null   int64
#  9   Polio                            2919 non-null   float64
#  10  Diphtheria                       2919 non-null   float64
#  11  GDP                              2490 non-null   float64
# ...

# %%
life_expectancy.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#        percentage expenditure       Measles   under-five deaths         Polio  \
# count             2938.000000    2938.000000         2938.000000  2919.000000
# mean               738.251295    2419.592240           42.035739    82.550188
# std               1987.914858   11467.272489          160.445548    23.428046
# ...

# %%
# Unique values in the various columns

# %%
print("Unique Values in 'Schooling'", list(life_expectancy.Schooling.unique()))
# Out:
# Unique Values in 'Schooling' [10.1, 10.0, 9.9, 9.8, 9.5, 9.2, 8.9, 8.7, 8.4, 8.1, 7.9, 6.8, 6.5, 6.2, 5.9, 5.5, 14.2, 13.3, 12.5, 12.2, 12.0, 11.6, 11.4, 10.8, 10.9, 10.7, 10.6, 14.4, 14.0, 13.6, 13.1, 12.6, 12.3, 11.7, 11.5, 11.1, 10.3, 9.4, 9.0, 8.5, 7.7, 7.2, 6.4, 5.1, 4.6, 13.9, 13.8, 14.1, 14.5, 14.7, 0.0, 17.3, 17.2, 17.1, 16.8, 16.5, 16.3, 16.1, 16.4, 15.6, 15.0, 12.7, 11.9, 11.2, 20.4, 20.3, 20.1, 19.8, 19.5, 19.1, 19.0, 20.7, 20.6, 20.5, 15.9, 15.7, 15.4, 15.3, 15.1, 15.2, 14.9, 15.5, 11.8, 11.0, 10.4, 12.4, 12.1, 13.7, 13.5, 13.2, 10.2, 8.6, 8.2, 7.5, 7.3, 15.8, 14.8, 14.6, 16.6, 16.2, 18.8, 18.6, 18.2, 18.0, 12.8, 12.9, 9.3, 9.1, 6.6, 10.5, 9.6, 8.8, 8.0, 7.6, 14.3, 13.4, 6.7, 6.3, 5.4, 4.9, 4.7, 4.3, 3.9, 3.8, 3.6, 3.5, 3.4, 5.6, 5.2, 4.4, 4.5, nan, 11.3, 9.7, 8.3, 7.1, 6.9, 6.0, 5.7, 5.3, 13.0, 17.6, 17.7, 16.0, 19.2, 18.7, 18.4, 16.9, 16.7, 5.0, 4.0, 3.7, 3.3, 2.9, 5.8, 17.0, 18.3, 18.1, 7.8, 7.0, 4.8, 7.4, 17.9, 18.5, 17.5, 6.1, 19.3, 19.7, 18.9, 17.4, 4.2, 3.1, 3.0, 2
# ...

# %%
print("Unique Values in 'Polio'", list(life_expectancy.Polio.unique()))
# Out:
# Unique Values in 'Polio' [6.0, 58.0, 62.0, 67.0, 68.0, 66.0, 63.0, 64.0, 5.0, 41.0, 36.0, 35.0, 24.0, 99.0, 98.0, 97.0, 95.0, 94.0, 92.0, 88.0, 86.0, 87.0, 89.0, 7.0, 75.0, 73.0, 81.0, 65.0, 39.0, 4.0, 37.0, 3.0, 96.0, 93.0, 91.0, 85.0, 9.0, 83.0, 84.0, 82.0, 71.0, 8.0, 79.0, 78.0, 77.0, 53.0, 74.0, 76.0, 69.0, 45.0, 72.0, 54.0, 59.0, 61.0, 57.0, 47.0, 23.0, 46.0, 44.0, 42.0, 38.0, 52.0, 51.0, 43.0, 32.0, 49.0, 31.0, 26.0, 17.0, 55.0, 48.0, 56.0, nan, 33.0]

# %%
# Ploting by Country

# %%
labels = life_expectancy['Country'].value_counts().index
values = life_expectancy['Country'].value_counts().values
colors = ['#cc99ee', '#66eb33']

# %%
first_chart = {'data' : [{'type' : 'pie', 
'name' : "Life Expectancy Chart: Pie chart",
'labels' : life_expectancy['Schooling'].value_counts().index,
'values' : life_expectancy['Schooling'].value_counts().values,
'direction' : 'clockwise',
'marker' : {'colors' : ['#9cc359', '#e96b5c']}}], 'layout' : {'title' : 'Schooling'}}
